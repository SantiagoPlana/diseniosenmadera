# %%
import pandas as pd

# %%
# df = pd.read_excel('LISTA PRECIOS ALGARROBO AGOSTO.xlsx')
df = pd.read_csv('Algarrobo1.csv')

# %%
df

# %%
for col in df.columns:
    if 'Unnamed' in col:
        df.drop(col, axis=1, inplace=True)

# %%
df

# %%
df.drop(labels=['LISTA', 'CONTADO'], axis=1, inplace=True)

# %%
df.rename({'LISTA.1': 'Precio de Lista', 'CONTADO.1': 'Precio de Contado'}, axis=1, inplace=True)

# %%
df.dropna(axis=0, subset=['SILLAS'], inplace=True)

# %%
df
# Out:
#                                 SILLAS Precio de Lista  Precio de Contado
# 0                                MAITE           15327           13027.95
# 1                              JULIANA           18850           16022.50
# 2                              AURELIA           15327           13027.95
# 3                         PARIS GRUESA           16900           14365.00
# 4                       ATLANTA GRUESA           16900           14365.00
# 5                                PAULA           15327           13027.95
# 7                                MESAS               0               0.00
# 8          METRO JULIAN PATA ALGARROBO           53200           45220.00
# 9              METRO DISEÑOS PATA PINO                                NaN
# 10                           OCTOGONAL           69846           59369.10
# 12                           MODULARES               0               0.00
# 13                   1 METRO ALEJANDRO          145457          123638.45
# ...

# %%
tipos = []
for i in df.index:
    if df.loc[i]['Precio de Lista'] == 0:
        tipos.append(df.loc[i]['SILLAS'])

# %%
df['Tipo de articulo'] = ''

# %%
for i in df.index:
    for x in tipos:
        if x in df.loc[i]['SILLAS']:
            df.loc[i, 'Tipo de articulo'] = x

# %%
df.loc[:5, 'Tipo de articulo'] = 'SILLA'

# %%
df.loc[7:12, 'Tipo de articulo'] = 'MESA'

# %%
df.loc[12:15, 'Tipo de articulo'] = 'MODULAR'

# %%
df.loc[17:18, 'Tipo de articulo'] = 'BAHIUT'
df.loc[22, 'Tipo de articulo'] = 'JUEGO LIVING'
df.loc[25:27, 'Tipo de articulo'] = 'AMOBLAMIENTO COCINA'
df.loc[30:38, 'Tipo de articulo'] = 'CAMA'
df.loc[41:42, 'Tipo de articulo'] = 'MESA DE LUZ'

# %%
df.to_csv('Algarrobo1.csv', index=False)

# %%
df = df[(df != 0).all(1)]

# %%
df.to_csv('Algarrobo1.csv', index=False)

# %%
df = df[['Tipo de articulo', 'SILLAS', 'Precio de Lista', 'Precio de Contado']]
# df = df.reindex(columns = new_order)

# %%
df.rename({'SILLAS': 'Modelo'}, axis=1, inplace=True)

# %%
df
# Out:
#        Tipo de articulo                              Modelo Precio de Lista  \
# 0                 SILLA                             JULIANA           18850
# 1                 SILLA                             AURELIA           15327
# 2                 SILLA                        PARIS GRUESA           16900
# 3                 SILLA                      ATLANTA GRUESA           16900
# 4                 SILLA                               PAULA           15327
# 5                  MESA         METRO JULIAN PATA ALGARROBO           53200
# 6                  MESA             METRO DISEÑOS PATA PINO
# 7                  MESA                           OCTOGONAL           69846
# 8               MODULAR                   1 METRO ALEJANDRO          145457
# 9               MODULAR                  2 METROS ALEJANDRO          279500
# 10              MODULAR              1 METRO DISEÑOS OFERTA          103857
# ...

# %%
#df1 = pd.read_excel('LISTA PRECIOS PINO ABRIL.xlsx')
df1 = pd.read_csv('Pino Precios Abril.csv')

# %%
df1
# Out:
#        Tipo De Articulo             Detalle        Lista C Miel      Cont Nat  \
# 0            Vestidores   Vestidor 1,20 nat   33214.50000000001  43344.922500
# 1            Vestidores  Vestidor 0,80 ryb   32465.180880000004  42367.061048
# 2            Vestidores                 S/D                   0      0.000000
# 3    Torneado 2 cuerpos                 S/D               43200  56376.000000
# 4       Sillon tapizado                 S/D                   0      0.000000
# ..                  ...                 ...                 ...           ...
# 134           1 mt asia                 S/D               15300  19966.500000
# 135                1 mt                 S/D                8380  10935.900000
# 136               0,8mt                 S/D                7390   9643.950000
# 137               0,6mt                 S/D                5990   7816.950000
# 138               0,4mt                 S/D                5490   7164.450000
#
# ...

# %%
for col in df1.columns:
    if 'Unnamed' in col:
        df1.drop(col, axis=1, inplace=True)

# %%
df1.rename({'GRUPO': 'Tipo de articulo'}, inplace=True, axis=1)

# %%
for col in df1.columns:
    df1.rename({col: col.title()}, axis=1, inplace=True)

# %%
df1['Tipo De Articulo'] = df1['Tipo De Articulo'].map(lambda x: x.capitalize())

# %%
df1['Detalle'] = df1['Detalle'].map(lambda x: x.capitalize() if isinstance(x, str) else x)

# %%
df1.to_csv('Pino Precios Abril', index=False)

# %%
df1.loc[:,['Lista C Miel', 'Cont Nat', 'Cont C Miel'] ] = df1.loc[:, ['Lista C Miel', 'Cont Nat', 'Cont C Miel']].fillna(0)

# %%
df1.loc[:, 'Cont C Alg'].fillna(0, inplace=True)

# %%
df1.loc[:, 'Detalle'].fillna('S/D', inplace=True)

# %%
df1[df1.Detalle == 'S/D']['Detalle'].count()
# Out:
# 63

# %%
df1.to_csv('Pino Precios Abril.csv', index=False)

# %%
serie_tipos = df1[(df1['Detalle'] == 'S/D') & (df1['Cont C Miel'] == 0)]['Tipo De Articulo']

# %%
serie_tipos.index
# Out:
# Int64Index([  2,   4,   9,  18,  22,  27,  42,  49,  50,  52,  53,  55,  56,
#              59,  60,  62,  64,  70,  77,  81,  82,  93, 100, 102, 103, 105,
#             117, 118, 119, 130],
#            dtype='int64')

# %%
df1.rename({'Tipo De Articulo': 'Articulo'}, axis=1, inplace=True)

# %%
for row_data in df1:
    print(row_data)
# Out:
# Articulo
# Detalle
# Lista C Miel
# Cont Nat
# Cont C Miel
# Cont C Alg

# %%
sd = df1[df1['Detalle'] == 'S/D']

# %%
sd[sd['Lista C Miel'] == '0']
# Out:
#         Tipo De Articulo Detalle Lista C Miel  Cont Nat  Cont C Miel  \
# 2             Vestidores     S/D            0       0.0          0.0
# 4        Sillon tapizado     S/D            0       0.0          0.0
# 9                 Sillas     S/D            0       0.0          0.0
# 18                 Racks     S/D            0       0.0          0.0
# 22       Perchero hierro     S/D            0       0.0          0.0
# 27      Modulares copero     S/D            0       0.0          0.0
# 42          Mesas de luz     S/D            0       0.0          0.0
# 49                 Mesas     S/D            0       0.0          0.0
# 50          Mesa ratona      S/D            0       0.0          0.0
# 52        Mesa cerealera     S/D            0       0.0          0.0
# 55         Lampara pino      S/D            0       0.0          0.0
# 56          Juego living     S/D            0       0.0          0.0
# 59     Esquinero pino tv     S/D            0       0.0          0.0
# ...

# %%
df1.rename({'Detalle': 'Modelo'}, axis=1, inplace=True)

# %%
df1.drop(index=9, axis=0, inplace=True)

# %%
df1.drop(index=2, axis=0, inplace=True)

# %%
df1.drop(index=[18, 26, 42, 49, 64, 70, 77, 81, 93, 105, 117, 118, 130, ], axis=0, inplace=True)

# %%
df1[:20]
# Out:
#       Tipo De Articulo              Modelo        Lista C Miel      Cont Nat  \
# 0           Vestidores   Vestidor 1,20 nat   33214.50000000001  43344.922500
# 1           Vestidores  Vestidor 0,80 ryb   32465.180880000004  42367.061048
# 3   Torneado 2 cuerpos                 S/D               43200  56376.000000
# 4      Sillon tapizado                 S/D                   0      0.000000
# 5               Sillas           Tapizadas  11292.930000000002  14737.273650
# 6               Sillas               Hindu           4603.5297   6007.606258
# 7               Sillas           Eco tapiz           6609.6855   8625.639577
# 8               Sillas                 Eco           4200.8802   5482.148661
# 10  Roperos (alz 35%+)          1,40 primo               30450  39737.250000
# 11  Roperos (alz 35%+)          1,20 primo               26090  34047.450000
# 12  Roperos (alz 35%+)          0,80 primo               21800  28449.000000
# ...

# %%
df1[df1['Tipo De Articulo'] == 'Mesas']['Tipo De Articulo'].apply(lambda x: x[:-1])
# Out:
# 43    Mesa
# 44    Mesa
# 45    Mesa
# 46    Mesa
# 47    Mesa
# 48    Mesa
# Name: Tipo De Articulo, dtype: object

# %%
df1.replace('Mesas', 'Mesa', inplace=True)

# %%
df1.to_csv('Pino Precios Abril.csv', index=False)

# %%
df1[df1['Tipo De Articulo'] == 'Sillas']
# Out:
#   Tipo De Articulo     Modelo        Lista C Miel      Cont Nat   Cont C Miel  \
# 5           Sillas  Tapizadas  11292.930000000002  14737.273650  16505.746488
# 6           Sillas      Hindu           4603.5297   6007.606258   6728.519010
# 7           Sillas  Eco tapiz           6609.6855   8625.639577   9660.716327
# 8           Sillas        Eco           4200.8802   5482.148661   6140.006500
#
#           Cont C Alg
# 5      16947.8646975
# 6  6908.747197274999
# 7  9919.485514124997
# 8  6304.470960149999

# %%
df1.replace('Sillas', 'Silla', inplace=True)

# %%
df1.replace('Vestidores', 'Vestidor', inplace=True)

# %%
df1.replace('Roperos (alz 35%+)', 'Ropero (alz 35%+)', inplace=True)

# %%
df1.replace('Organizadores', 'Organizador', inplace=True)
df1.replace('Modulares', 'Modular', inplace=True)
df1.replace('Mesas de luz', 'Mesa de luz', inplace=True)
df1.replace('Canasteros', 'Canastero', inplace=True)
df1.replace('Camas', 'Cama', inplace=True)
df1.replace('Cajoneras', 'Cajonera', inplace=True)

# %%
sd = df1[df1['Modelo'] == 'S/D']

# %%
sd
# Out:
#            Tipo De Articulo Modelo        Lista C Miel      Cont Nat  \
# 3        Torneado 2 cuerpos    S/D               43200  56376.000000
# 4           Sillon tapizado    S/D                   0      0.000000
# 17          Recto 2 cuerpos    S/D  32400.000000000004  42282.000000
# 19           Rack asia 2,00    S/D               41890  54666.450000
# 20           Rack asia 1,60    S/D               35000  45675.000000
# 21         Perchero vikingo    S/D                6090   7947.450000
# 22          Perchero hierro    S/D                   0      0.000000
# 27         Modulares copero    S/D                   0      0.000000
# 50             Mesa ratona     S/D                   0      0.000000
# 52           Mesa cerealera    S/D                   0      0.000000
# 53         Lcd vintage 1,20    S/D                          0.000000
# 54            Lcd asia bajo    S/D               12500  16312.500000
# 55            Lampara pino     S/D                   0      0.000000
# ...

# %%
mods = df1[df1['Tipo De Articulo'].str.contains('Biblio') == True]['Tipo De Articulo'].apply(lambda x: x.split(' ')[1:])

# %%
df1.loc[
    df1['Tipo De Articulo'].str.contains('Biblio') == True]['Modelo'] = mods
# Out:
# <ipython-input-117-a17bbfad8938>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[

# %%
df1.loc[106:113, 'Modelo'] = df1[df1['Tipo De Articulo'].str.contains('Biblio') == True]['Tipo De Articulo'].apply(lambda x: x.split(' ')[1:])

# %%
df1.loc[106:113, 'Modelo'] = df1.loc[106:113]['Modelo'].apply(lambda x: x[0] + ' ' + x[1])

# %%
df1.loc[106:113, 'Tipo De Articulo'] = 'Biblioteca'

# %%
df1.loc[106:113]
# Out:
#     Tipo De Articulo      Modelo        Lista C Miel      Cont Nat  \
# 106       Biblioteca  recta 1,00  12966.723000000004  16921.573515
# 107       Biblioteca  recta 0,80  12349.260000000002  16115.784300
# 108       Biblioteca  recta 0,60             11226.6  14650.713000
# 109       Biblioteca  recta 0,40               10692  13953.060000
# 110       Biblioteca   asia 1,00               14500  18922.500000
# 111       Biblioteca   asia 0,80               13500  17617.500000
# 112       Biblioteca   asia 0,60               12500  16312.500000
# 113       Biblioteca   asia 0,40               11800  15399.000000
#
#       Cont C Miel          Cont C Alg
# 106  18952.162337      19459.80954225
# 107  18049.678416  18533.151944999998
# 108  16408.798560  16848.319949999997
# 109  15627.427200           16046.019
# 110  21193.200000           21760.875
# 111  19731.600000           20260.125
# 112  18270.000000           18759.375
# 113  17246.880000            17708.85

# %%
df1.to_csv('Pino Precios Abril.csv', index=False)

# %%
df1 = pd.read_csv('Pino Precios Abril.csv')

# %%
df1[0:20]
# Out:
#       Tipo De Articulo              Modelo        Lista C Miel      Cont Nat  \
# 0             Vestidor   Vestidor 1,20 nat   33214.50000000001  43344.922500
# 1             Vestidor  Vestidor 0,80 ryb   32465.180880000004  42367.061048
# 2   Torneado 2 cuerpos                 S/D               43200  56376.000000
# 3      Sillon tapizado                 S/D                   0      0.000000
# 4                Silla           Tapizadas  11292.930000000002  14737.273650
# 5                Silla               Hindu           4603.5297   6007.606258
# 6                Silla           Eco tapiz           6609.6855   8625.639577
# 7                Silla                 Eco           4200.8802   5482.148661
# 8    Ropero (alz 35%+)          1,40 primo               30450  39737.250000
# 9    Ropero (alz 35%+)          1,20 primo               26090  34047.450000
# 10   Ropero (alz 35%+)          0,80 primo               21800  28449.000000
# ...

# %%
df1.loc[16:17, 'Modelo'] = df1.loc[16:17, 'Tipo De Articulo'].apply(lambda x: x.split(' ')[1:])
df1.loc[16:17, 'Modelo'] = df1.loc[16:17, 'Modelo'].apply(lambda x: x[0] + ' ' + x[1])

# %%
df1.loc[18:19, 'Modelo'] = df1.loc[18:19, 'Tipo De Articulo'].apply(lambda x: x.split(' ')[1].capitalize())

# %%
df1.loc[18:40, 'Tipo De Articulo'] = df1.loc[18:40, 'Tipo De Articulo'].apply(lambda x: x.split(' ')[0])

# %%
df1.loc[57, 'Modelo'] = ' '.join(df1.loc[57, 'Tipo De Articulo'].split(' ')[1:])

# %%
df1.loc[57, 'Tipo De Articulo'] = df1.loc[57, 'Tipo De Articulo'].split(' ')[0]

# %%
df1.loc[89, 'Modelo'] = ' '.join(df1.loc[89, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[90, 'Modelo'] = ' '.join(df1.loc[90, 'Tipo De Articulo'].split(' ')[1:])

# %%
df1.loc[89, 'Tipo De Articulo'] = 'Cajonera'
df1.loc[90, 'Tipo De Articulo'] = 'Cajonera'

# %%
df1.loc[91, 'Modelo'] = ' '.join(df1.loc[91, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[92, 'Modelo'] = ' '.join(df1.loc[92, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[93, 'Modelo'] = ' '.join(df1.loc[93, 'Tipo De Articulo'].split(' ')[1:])

# %%
df1.loc[91, 'Tipo De Articulo'] = 'Botinero'
df1.loc[92, 'Tipo De Articulo'] = 'Botinero'
df1.loc[93, 'Tipo De Articulo'] = 'Botinero'

# %%
df1.loc[105, 'Modelo'] = ' '.join(df1.loc[105, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[106, 'Modelo'] = ' '.join(df1.loc[106, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[107, 'Modelo'] = ' '.join(df1.loc[107, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[108, 'Modelo'] = ' '.join(df1.loc[108, 'Tipo De Articulo'].split(' ')[1:])
df1.loc[109, 'Modelo'] = ' '.join(df1.loc[109, 'Tipo De Articulo'].split(' ')[1:])

df1.loc[105, 'Tipo De Articulo'] = ' '.join(df1.loc[105, 'Tipo De Articulo'].split(' ')[0])
df1.loc[106, 'Tipo De Articulo'] = ' '.join(df1.loc[106, 'Tipo De Articulo'].split(' ')[0])
df1.loc[107, 'Tipo De Articulo'] = ' '.join(df1.loc[107, 'Tipo De Articulo'].split(' ')[0])
df1.loc[108, 'Tipo De Articulo'] = ' '.join(df1.loc[108, 'Tipo De Articulo'].split(' ')[0])
df1.loc[109, 'Tipo De Articulo'] = ' '.join(df1.loc[109, 'Tipo De Articulo'].split(' ')[0])

# %%
df1.loc[105, 'Tipo De Articulo'] = 'Barra'
df1.loc[106, 'Tipo De Articulo'] = 'Barra'
df1.loc[107, 'Tipo De Articulo'] = 'Barra'
df1.loc[108, 'Tipo De Articulo'] = 'Barra'
df1.loc[109, 'Tipo De Articulo'] = 'Barra'

# %%
df1.to_csv('Pino Precios Abril.csv', index=False)

# %%
df1.loc[101:120]
# Out:
#     Tipo De Articulo        Modelo        Lista C Miel      Cont Nat  \
# 101       Biblioteca     asia 0,40               11800  15399.000000
# 102            Bayut   1,60 ronald   38528.82000000001  50280.110100
# 103            Bayut   1,20 ronald          28823.5431  37614.723745
# 104            Bayut   1,40 ronald               32000  41760.000000
# 105            Barra       l roble                   0      0.000000
# 106            Barra        l 1,40  42934.560000000005  56029.600800
# 107            Barra        l 1,20               38890  50751.450000
# 108            Barra    1,40 recto               35050  45740.250000
# 109            Barra    1,20 recto               31190  40702.950000
# 110  Amob. de cocina   Alcena 1,60  17058.967200000003  22261.952196
# 111  Amob. de cocina  Alacena 1,40  15996.103200000005  20874.914676
# 112  Amob. de cocina  Alacena 1,20  14880.096000000005  19418.525280
# 113  Amob. de cocina     Bajo 1,60  26040.168000000005  33982.419240
# ...

# %%
df_alg = pd.read_csv('Algarrobo1.csv')

# %%
df_pino = pd.read_csv('Pino Precios Abril.csv')

# %%
df_alg
# Out:
#                                 SILLAS Precio de Lista  Precio de Contado  \
# 0                              JULIANA           18850           16022.50
# 1                              AURELIA           15327           13027.95
# 2                         PARIS GRUESA           16900           14365.00
# 3                       ATLANTA GRUESA           16900           14365.00
# 4                                PAULA           15327           13027.95
# 5          METRO JULIAN PATA ALGARROBO           53200           45220.00
# 6              METRO DISEÑOS PATA PINO                                NaN
# 7                            OCTOGONAL           69846           59369.10
# 8                    1 METRO ALEJANDRO          145457          123638.45
# 9                   2 METROS ALEJANDRO          279500          237575.00
# 10              1 METRO DISEÑOS OFERTA          103857           88278.45
# 11           1,50 X 1,00 MTS ALEJANDRO          105300           89505.00
# ...

# %%
df_alg.loc[29, 'Tipo de articulo'] = 'MESA'

# %%
df_alg = df_alg.sort_values('Tipo de articulo', axis=0)

# %%
df_alg.reset_index(drop=True, inplace=True)

# %%
df_alg.loc[18, ['Precio de Lista', 'Precio de Contado']] = 0

# %%
df_alg['Precio de Lista'] = df_alg['Precio de Lista'].astype(dtype=float)

# %%
df_alg
# Out:
#                                 SILLAS  Precio de Lista  Precio de Contado  \
# 0                  BAJO Y ALACENA 1,40         164957.0          140213.45
# 1                  BAJO Y ALACENA 1,60         188695.0          160390.75
# 2                  BAJO Y ALACENA 1,20         141557.0          120323.45
# 3            1,50 X 1,00 MTS ALEJANDRO         105300.0           89505.00
# 4             CAMA 1,40 ESTANCIERA MRK          56160.0           47736.00
# 5              CAMA 1,40 GRIEGA JULIAN          51857.0           44078.45
# 6                 CAMA 1,40 TIMON ALEJ          51857.0           44078.45
# 7           CAMA CABECERA PIECERA TORN          29757.0           25293.45
# 8           CAMA 0,80 DISEÑOS TORNEADA          29757.0           25293.45
# 9             CAMA 0,80 TABLERO JULIAN          29757.0           25293.45
# 10                 CAMA 1,40 TIMON MRK          56160.0           47736.00
# ...

# %%
df_pino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tipo De Articulo  124 non-null    object
#  1   Modelo            124 non-null    object
#  2   Lista C Miel      124 non-null    object
#  3   Cont Nat          124 non-null    float64
#  4   Cont C Miel       124 non-null    float64
#  5   Cont C Alg        124 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 5.9+ KB

# %%
try:
    df_pino[['Lista C Miel', 'Cont C Alg']] = df_pino[['Lista C Miel', 'Cont C Alg']].astype(dtype=float) 
except ValueError:
    pass

# %%
df_pino.loc[0:40, ['Lista C Miel', 'Cont C Alg']]
# Out:
#           Lista C Miel          Cont C Alg
# 0    33214.50000000001  49846.660875000016
# 1   32465.180880000004  48722.120205659994
# 2                43200  64832.399999999994
# 3                    0                   0
# 4   11292.930000000002       16947.8646975
# 5            4603.5297   6908.747197274999
# 6            6609.6855   9919.485514124997
# 7            4200.8802   6304.470960149999
# 8                30450  45697.837499999994
# 9                26090   39154.56749999999
# 10               21800            32716.35
# 11   62718.01034400001     94124.054023758
# 12  47828.880000000005         71779.19166
# 13          32311.0656  48490.831699200004
# 14               22250          33391.6875
# 15  32400.000000000004  48624.299999999996
# 16               41890   62866.41749999999
# 17               35000   52526.24999999999
# 18                6090           9139.5675
# 19                   0                   0
# 20           21522.996        32300.636247
# ...

# %%
float(df_pino.loc[33, 'Lista C Miel'])
# Out:
# 16890.0

# %%
df_pino['Lista C Miel'].index
# Out:
# RangeIndex(start=0, stop=124, step=1)

# %%
df_pino.loc[47, 'Lista C Miel'] = 0.0
df_pino.loc[112, 'Cont C Alg'] = 0.0

# %%
for i in df_pino['Lista C Miel'].index:
    if not isinstance(df_pino.loc[i, 'Lista C Miel'], float):
        df_pino.loc[i, 'Lista C Miel'] = float(df_pino.loc[i, 'Lista C Miel'])

# %%
floats = []
for i in df_pino['Lista C Miel'].index:
    if isinstance(df_pino.loc[i, 'Lista C Miel'], float):
        print(df_pino.loc[i, 'Lista C Miel'])
        floats.append(i)

# %%
df_pino[['Lista C Miel', 'Cont C Alg']] = df_pino[['Lista C Miel', 'Cont C Alg']].astype(float)

# %%
df_pino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tipo De Articulo  124 non-null    object
#  1   Modelo            124 non-null    object
#  2   Lista C Miel      124 non-null    float64
#  3   Cont Nat          124 non-null    float64
#  4   Cont C Miel       124 non-null    float64
#  5   Cont C Alg        124 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 5.9+ KB

# %%
df_alg.rename({'SILLAS': 'Modelo'}, axis=1, inplace=True)

# %%
df_alg = df_alg[['Tipo de articulo', 'Modelo', 'Precio de Lista', 'Precio de Contado']]

# %%
df_alg
# Out:
#        Tipo de articulo                              Modelo  Precio de Lista  \
# 0   AMOBLAMIENTO COCINA                 BAJO Y ALACENA 1,40         164957.0
# 1   AMOBLAMIENTO COCINA                 BAJO Y ALACENA 1,60         188695.0
# 2   AMOBLAMIENTO COCINA                 BAJO Y ALACENA 1,20         141557.0
# 3                BAHIUT           1,50 X 1,00 MTS ALEJANDRO         105300.0
# 4                  CAMA            CAMA 1,40 ESTANCIERA MRK          56160.0
# 5                  CAMA             CAMA 1,40 GRIEGA JULIAN          51857.0
# 6                  CAMA                CAMA 1,40 TIMON ALEJ          51857.0
# 7                  CAMA          CAMA CABECERA PIECERA TORN          29757.0
# 8                  CAMA          CAMA 0,80 DISEÑOS TORNEADA          29757.0
# 9                  CAMA            CAMA 0,80 TABLERO JULIAN          29757.0
# 10                 CAMA                 CAMA 1,40 TIMON MRK          56160.0
# ...

# %%
df_alg.to_csv('Algarrobo1.csv', index=False)

# %%
df_pino.drop(23, axis=0, inplace=True)

# %%
df_pino[90:130]
# Out:
#     Tipo De Articulo        Modelo  Lista C Miel      Cont Nat   Cont C Miel  \
# 91          Botinero      vertical       0.00000      0.000000      0.000000
# 92          Botinero    doble bajo       0.00000      0.000000      0.000000
# 93          Botinero       cimino        0.00000  24875.000000  27860.000000
# 94        Biblioteca    recta 1,00   12966.72300  16921.573515  18952.162337
# 95        Biblioteca    recta 0,80   12349.26000  16115.784300  18049.678416
# 96        Biblioteca    recta 0,60   11226.60000  14650.713000  16408.798560
# 97        Biblioteca    recta 0,40   10692.00000  13953.060000  15627.427200
# 98        Biblioteca     asia 1,00   14500.00000  18922.500000  21193.200000
# 99        Biblioteca     asia 0,80   13500.00000  17617.500000  19731.600000
# 100       Biblioteca     asia 0,60   12500.00000  16312.500000  18270.000000
# 101       Biblioteca     asia 0,40   11800.00000  15399.000000  17246.880000
# ...

# %%
df_pino['Cantidad'] = 0

# %%
df_pino
# Out:
#        Tipo De Articulo              Modelo  Lista C Miel      Cont Nat  \
# 0              Vestidor   Vestidor 1,20 nat   33214.50000  43344.922500
# 1              Vestidor  Vestidor 0,80 ryb    32465.18088  42367.061048
# 2    Torneado 2 cuerpos                 S/D   43200.00000  56376.000000
# 3       Sillon tapizado                 S/D       0.00000      0.000000
# 4                 Silla           Tapizadas   11292.93000  14737.273650
# ..                  ...                 ...           ...           ...
# 119           1 mt asia                 S/D   15300.00000  19966.500000
# 120                1 mt                 S/D    8380.00000  10935.900000
# 121               0,8mt                 S/D    7390.00000   9643.950000
# 122               0,6mt                 S/D    5990.00000   7816.950000
# 123               0,4mt                 S/D    5490.00000   7164.450000
#
#       Cont C Miel    Cont C Alg  Cantidad
# 0    48546.313200  49846.660875         0
# ...

# %%
df_alg['Cantidad'] = 0
# Out:
# <ipython-input-87-4955fb7cc2d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alg['Cantidad'] = 0

# %%
df_pino.loc[120:, 'Modelo'] = df_pino.loc[120:, 'Tipo De Articulo']

# %%
df_pino.loc[120:, 'Tipo De Articulo'] = 'Mesa de arrime'

# %%
df_pino.loc[117:119, 'Modelo'] = df_pino.loc[117:119, 'Tipo De Articulo']

# %%
df_pino.loc[117:119, 'Tipo De Articulo'] = 'Escritorio'

# %%
df_pino[100:]
# Out:
#     Tipo De Articulo        Modelo  Lista C Miel      Cont Nat   Cont C Miel  \
# 101       Biblioteca     asia 0,40   11800.00000  15399.000000  17246.880000
# 102            Bayut   1,60 ronald   38528.82000  50280.110100  56313.723312
# 103            Bayut   1,20 ronald   28823.54310  37614.723745  42128.490595
# 104            Bayut   1,40 ronald   32000.00000  41760.000000  46771.200000
# 105            Barra       l roble       0.00000      0.000000      0.000000
# 106            Barra        l 1,40   42934.56000  56029.600800  62753.152896
# 107            Barra        l 1,20   38890.00000  50751.450000  56841.624000
# 108            Barra    1,40 recto   35050.00000  45740.250000  51229.080000
# 109            Barra    1,20 recto   31190.00000  40702.950000  45587.304000
# 110  Amob. de cocina   Alcena 1,60   17058.96720  22261.952196  24933.386460
# 111  Amob. de cocina  Alacena 1,40   15996.10320  20874.914676  23379.904437
# ...

# %%
df_pino.loc[116, 'Modelo'] =  df_pino.loc[116, 'Tipo De Articulo']

# %%
df_pino.loc[116, 'Tipo De Articulo'] = 'Escritorio'

# %%
df_pino[100:]
# Out:
#     Tipo De Articulo        Modelo  Lista C Miel      Cont Nat   Cont C Miel  \
# 101       Biblioteca     asia 0,40   11800.00000  15399.000000  17246.880000
# 102            Bayut   1,60 ronald   38528.82000  50280.110100  56313.723312
# 103            Bayut   1,20 ronald   28823.54310  37614.723745  42128.490595
# 104            Bayut   1,40 ronald   32000.00000  41760.000000  46771.200000
# 105            Barra       l roble       0.00000      0.000000      0.000000
# 106            Barra        l 1,40   42934.56000  56029.600800  62753.152896
# 107            Barra        l 1,20   38890.00000  50751.450000  56841.624000
# 108            Barra    1,40 recto   35050.00000  45740.250000  51229.080000
# 109            Barra    1,20 recto   31190.00000  40702.950000  45587.304000
# 110  Amob. de cocina   Alcena 1,60   17058.96720  22261.952196  24933.386460
# 111  Amob. de cocina  Alacena 1,40   15996.10320  20874.914676  23379.904437
# ...

# %%
df_pino[0:20]
# Out:
#       Tipo De Articulo              Modelo  Lista C Miel      Cont Nat  \
# 0             Vestidor   Vestidor 1,20 nat  33214.500000  43344.922500
# 1             Vestidor  Vestidor 0,80 ryb   32465.180880  42367.061048
# 2   Torneado 2 cuerpos                 S/D  43200.000000  56376.000000
# 3      Sillon tapizado                 S/D      0.000000      0.000000
# 4                Silla           Tapizadas  11292.930000  14737.273650
# 5                Silla               Hindu   4603.529700   6007.606258
# 6                Silla           Eco tapiz   6609.685500   8625.639577
# 7                Silla                 Eco   4200.880200   5482.148661
# 8    Ropero (alz 35%+)          1,40 primo  30450.000000  39737.250000
# 9    Ropero (alz 35%+)          1,20 primo  26090.000000  34047.450000
# 10   Ropero (alz 35%+)          0,80 primo  21800.000000  28449.000000
# 11   Ropero (alz 35%+)  1,60 x 0,55 ronald  62718.010344  81847.003499
# ...

# %%
df_pino.to_csv('Pino Precios Abril.csv', index=False)

# %%
df_pino.loc[2, 'Modelo'] = df_pino.loc[2, 'Tipo De Articulo']
df_pino.loc[2, 'Tipo De Articulo'] = 'Sillon'

# %%
df_pino.loc[15, 'Modelo'] = df_pino.loc[15, 'Tipo De Articulo']
df_pino.loc[15, 'Tipo De Articulo'] = 'Sillon'

# %%
df_pino[21:60]
# Out:
#      Tipo De Articulo           Modelo  Lista C Miel      Cont Nat  \
# 21        Organizador              4+1   12621.51000  16471.070550
# 22        Organizador              3+1   11943.93420  15586.834131
# 24            Modular    1,80 imperial   31274.77320  40813.579026
# 25            Modular      1,60 ronald   39100.10940  51025.642767
# 26            Modular      1,20 ronald   31274.77320  40813.579026
# 27            Modular      0,80 ronald   23396.29380  30532.163409
# 28            Modular      1,40 ronald   36708.66540  47904.808347
# 29            Modular         1,40 rjm   33958.50480  44315.848764
# 30            Modular         1,20 rjm   29806.69230  38897.733452
# 31            Modular         0,75 rjm   18055.40220  23562.299871
# 32            Modular      0,40 palito   18586.83420  24255.818631
# 33            Modular   Mod barg c cop   16890.00000  22041.450000
# 34               Mesa       Vintag rjm    7958.19420  10385.443431
# ...

# %%
df_pino.loc[47, 'Modelo'] = df_pino.loc[47, 'Tipo De Articulo']
df_pino.loc[48, 'Modelo'] = df_pino.loc[48, 'Tipo De Articulo']
df_pino.loc[47, 'Tipo De Articulo'] = 'Rack'
df_pino.loc[48, 'Tipo De Articulo'] = 'Rack'

# %%
df_pino['Tipo De Articulo'].value_counts()
# Out:
# Modular              10
# Mesa                 10
# Camas                10
# Cajonera              8
# Biblioteca            8
# Ropero (alz 35%+)     6
# Cimino am de coc.     6
# Amob. de cocina       6
# Mesa de arrime        5
# Barra                 5
# Escritorio            5
# Silla                 4
# Organizador           3
# Botinero              3
# Bayut                 3
# Canastero             3
# Cimino ropero         3
# Sillon                2
# Cimino m. de luz      2
# Rack                  2
# Perchero              2
# Vestidor              2
# Lampara pino          1
# Mesa cerealera        1
# Rack asia 2,00        1
# Juego living          1
# Mesa ratona           1
# Esquinero pino tv     1
# Ropero eco            1
# Sillon tapizado       1
# Camastro              1
# Comoda                1
# Isla 1,20             1
# Dressuar              1
# Despensero micro      1
# Futon c colch         1
# Rack asia 1,60        1
# ...

# %%
df_pino[df_pino['Tipo De Articulo'] == 'Rack asia 2,00']
# Out:
#    Tipo De Articulo     Modelo  Lista C Miel  Cont Nat  Cont C Miel  \
# 16   Rack asia 2,00  asia 2,00       41890.0  54666.45    61226.424
#
#     Cont C Alg  Cantidad
# 16  62866.4175         0

# %%
df_pino.loc[17, 'Tipo De Articulo'] = df_pino.loc[17, 'Tipo De Articulo'].split(' ')[0]

# %%
df_pino.loc[16, 'Tipo De Articulo'] = df_pino.loc[16, 'Tipo De Articulo'].split(' ')[0]

# %%
df_pino.loc[16, 'Tipo De Articulo']
# Out:
# 'Rack'

# %%
df_pino.sort_values(by=['Tipo De Articulo', 'Lista C Miel'], axis=0)
df_pino.reset_index(drop=True, inplace=True)

# %%
df_pino['Tipo De Articulo'].value_counts()
# Out:
# Modular              10
# Mesa                 10
# Camas                10
# Biblioteca            8
# Cajonera              8
# Amob. de cocina       6
# Ropero (alz 35%+)     6
# Cimino am de coc.     6
# Escritorio            5
# Mesa de arrime        5
# Barra                 5
# Rack                  4
# Silla                 4
# Botinero              3
# Cimino ropero         3
# Canastero             3
# Bayut                 3
# Organizador           3
# Perchero              2
# Vestidor              2
# Cimino m. de luz      2
# Sillon                2
# Mesa ratona           1
# Juego living          1
# Mesa cerealera        1
# Comoda                1
# Ropero eco            1
# Esquinero pino tv     1
# Isla 1,20             1
# Dressuar              1
# Futon c colch         1
# Sillon tapizado       1
# Lampara pino          1
# Despensero micro      1
# Camastro              1
# Name: Tipo De Articulo, dtype: int64

# %%
df_alg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tipo de articulo   31 non-null     object
#  1   Modelo             31 non-null     object
#  2   Precio de Lista    31 non-null     float64
#  3   Precio de Contado  31 non-null     float64
#  4   Cantidad           31 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.5+ KB

# %%
df_alg['Material'] = 'Algarrobo'
df_pino['Material'] = 'Pino'
# Out:
# <ipython-input-139-154c4b3e1f98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alg['Material'] = 'Algarrobo'

# %%
df_pino.rename({'Tipo de Articulo': 'Tipo de articulo'}, axis=1, inplace=True)

# %%
df_alg['Tipo de articulo'] = df_alg['Tipo de articulo'].apply(lambda x: x.capitalize())
# Out:
# <ipython-input-153-9abe412024b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alg['Tipo de articulo'] = df_alg['Tipo de articulo'].apply(lambda x: x.capitalize())

# %%
df_alg.loc[:, 'Modelo'] = df_alg['Modelo'].apply(lambda x: x.capitalize())
# Out:
# C:\Users\Santiago\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_alg
# Out:
#        Tipo de articulo                              Modelo  Precio de Lista  \
# 0   Amoblamiento cocina                 Bajo y alacena 1,40         164957.0
# 1   Amoblamiento cocina                 Bajo y alacena 1,60         188695.0
# 2   Amoblamiento cocina                 Bajo y alacena 1,20         141557.0
# 3                Bahiut           1,50 x 1,00 mts alejandro         105300.0
# 4                  Cama            Cama 1,40 estanciera mrk          56160.0
# 5                  Cama             Cama 1,40 griega julian          51857.0
# 6                  Cama                Cama 1,40 timon alej          51857.0
# 7                  Cama          Cama cabecera piecera torn          29757.0
# 8                  Cama          Cama 0,80 diseños torneada          29757.0
# 9                  Cama            Cama 0,80 tablero julian          29757.0
# 10                 Cama                 Cama 1,40 timon mrk          56160.0
# ...

# %%
df_alg.to_csv('Algarrobo1.csv', index=False)
df_pino.to_csv('Pino Precios Abril.csv', index=False)

# %%
df_join = pd.concat([df_pino, df_alg], sort=False)

# %%
df_join = df_join[['Material','Tipo de articulo', 'Modelo', 'Cantidad', 'Lista C Miel', 'Cont Nat', 'Cont C Miel', 'Cont C Alg', 'Precio de Lista', 'Precio de Contado' ]]

# %%
df_join.to_csv('Stock.csv', index=False)
